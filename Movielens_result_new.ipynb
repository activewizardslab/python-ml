# %% [markdown]
# ## Movielens

# %% [markdown]
# #### 1. Loading modules.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Reading data.

# %%
# we are using pandas "read_table" to extract data from raw files
movies=pd.read_table('movies.dat.txt',delimiter='::', header=None, names=["MovieID", "Title", "Genres"])
ratings=pd.read_table('ratings.dat.txt',delimiter='::', header=None, names=["UserID", "MovieID", "Rating", "Timestamp"])
users=pd.read_table('users.dat.txt',delimiter='::', header=None, names=["UserID", "Gender", "Age", "Occupation", "Zip-code"])

# %% [markdown]
# #### 3. Preparing data.

# %%
#Using pandas’s merge function, we first merge ratings with users then merging that result with the movies data. 
data = pd.merge(pd.merge(ratings, users), movies)
data.head(n=5)
# Out:
#    UserID  MovieID  Rating  Timestamp Gender  Age  Occupation Zip-code  \
# 0       1     1193       5  978300760      F    1          10    48067
# 1       2     1193       5  978298413      M   56          16    70072
# 2      12     1193       4  978220179      M   25          12    32793
# 3      15     1193       4  978199279      M   25           7    22903
# 4      17     1193       5  978158471      M   50           1    95350
#
#                                     Title Genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# #### 4. Call describe for some data.

# %%
data[['Rating', 'Age']].describe()
# Out:
#                Rating             Age
# count  1000209.000000  1000209.000000
# mean         3.581564       29.738314
# std          1.117102       11.751983
# min          1.000000        1.000000
# 25%          3.000000       25.000000
# 50%          4.000000       25.000000
# 75%          4.000000       35.000000
# max          5.000000       56.000000

# %% [markdown]
# What we see:
#
# - people, who watches movies, are less then 56 years old;
#
# - most common age is less then 35;
#
# - average age is about 30 years;
#
# - average rating is more than 3.5 stars.

# %% [markdown]
# #### 5. Most common ratings.

# %%
# %pylab inline
# we are using matplotlib library to plot histogram, which show most common ratings in this dataset. 
plt.hist(data.Rating, bins=10, color='blue', alpha=0.8)
plt.xlabel("Stars")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# We can see:
#
# - people like a big part of movies and evaluate them from 3 to 5 stars.

# %% [markdown]
# #### 6. Find mean movie ratings for each film grouped by gender.

# %%
# we are using DataFrame's pivot_table method that allow group data by column very easy. 
mean_ratings = data.pivot_table('Rating', rows='Genres', cols='Gender', aggfunc = 'mean')

# %%
# we want to find the genres of movies by gender. 
# we can add a column to mean_ratings containing the difference in means, then sort by that.
mean_ratings['diff'] = mean_ratings['F'] - mean_ratings['M']
sorted_by_diff = mean_ratings.sort_index(by='diff')
sorted_by_diff[:10]
# Out:
# Gender                                                  F         M      diff
# Genres
# Comedy|Film-Noir|Thriller                        1.000000  2.250000 -1.250000
# Crime|Mystery                                    2.687500  3.360656 -0.673156
# Action|Adventure|Comedy|Horror                   3.297297  3.909283 -0.611985
# Action|Western                                   3.541667  4.144167 -0.602500
# Action|Animation|Children's|Sci-Fi|Thriller|War  2.857143  3.433333 -0.576190
# Action|Adventure|Drama|Thriller                  2.956522  3.483146 -0.526624
# Action|Comedy|Crime|Horror|Thriller              2.735714  3.232558 -0.496844
# Adventure|Animation|Sci-Fi|Thriller              3.511111  3.980344 -0.469233
# Drama|Romance|Sci-Fi                             3.615385  4.040816 -0.425432
# Action|Comedy|War                                2.873016  3.291971 -0.418955

# %% [markdown]
# What we see:
#
# - top 10 genres of movies that men find better.

# %% [markdown]
# #### 7. Do really only women watch movies of the genre Romance?

# %%
# count all genres of movies and group by gender
count_romance = data.pivot_table('Rating', rows='Genres', cols='Gender', aggfunc = 'count')

# %%
count_romance[:10]
# Out:
# Gender                                            F      M
# Genres
# Action                                         1611  10700
# Action|Adventure                               1978   8468
# Action|Adventure|Animation                       64    281
# Action|Adventure|Animation|Children's|Fantasy    41     94
# Action|Adventure|Animation|Horror|Sci-Fi         71    547
# Action|Adventure|Children's                       4     40
# Action|Adventure|Children's|Comedy              123    395
# Action|Adventure|Children's|Fantasy               7     37
# Action|Adventure|Children's|Sci-Fi               55    295
# Action|Adventure|Comedy                         433   1644

# %%
# count number of women and men who watch Romance genre.
num_female_romance=0
num_male_romance=0

for i in range(len(count_romance.index)):
    if (count_romance.index[i].startswith("Romance")) == True:
        num_female_romance += count_romance.F[i]
        num_male_romance += count_romance.M[i]
print num_female_romance, num_male_romance
# Out:
# 1189.0 1643.0

# %%
# count general number all women and men in dataset 
num_female = count_romance.F.sum()
num_male = count_romance.M.sum()
num_female, num_male
# Out:
# (246440.0, 753769.0)

# %%
# find percentage of the people who watch the movies to all viewers by gender
f = 100 * float(num_female_romance)/float(num_female) 
m = 100 * float(num_male_romance)/float(num_male)
f, m
# Out:
# (0.48247037818535954, 0.21797128828593376)

# %% [markdown]
# We can see that the number of women who watch romances is more than double in comparison with the number of men.

# %%
# find position of Romance genre
for i in range(len(mean_ratings.index)):
    if (mean_ratings.index[i].startswith("Romance")) == True:
        print i
# Out:
# 290
# 291
# 292
# 293

# %%
# how women and men evaluate movies in genre Romance? The column "diff" show difference between rating each gender.  
romance_mean  = mean_ratings[290:294]
romance_mean.index = range(len(romance_mean))
print romance_mean
# Out:
# Gender         F         M      diff
# 0       3.560000  3.261682  0.298318
# 1       4.004310  3.784848  0.219462
# 2       3.565217  3.285714  0.279503
# 3       3.363636  3.711538 -0.347902

# %%
# find mean of rating for Romance
romance_mean.F.mean(), romance_mean.M.mean()
# Out:
# (3.6232910249420742, 3.5109458687729718)

# %%
# find difference between means
diff = romance_mean.F.mean() - romance_mean.M.mean()
diff
# Out:
# 0.11234515616910246

# %% [markdown]
# Women give a romance a bit higher rating than men.

# %% [markdown]
# #### 8. Which movies do men and women most disagree on?

# %%
# we have DataFrame with multi-level index,  therefore we must return new DataFrame with labeling information in the columns under the index names
data.reset_index('MovieID', inplace=True)

# %%
# we want to find the movies that are most divisive between male and female.
data1 = data.pivot_table(rows=['MovieID','Title'], cols=['Gender'], values='Rating', fill_value=0)
print data1.head()
# Out:
# Gender                                             F         M
# MovieID Title
# 1       Toy Story (1995)                    4.187817  4.130552
# 2       Jumanji (1995)                      3.278409  3.175238
# 3       Grumpier Old Men (1995)             3.073529  2.994152
# 4       Waiting to Exhale (1995)            2.976471  2.482353
# 5       Father of the Bride Part II (1995)  3.212963  2.888298

# %%
# 'diff' gives us the movies with rating difference and which were preferred by women
data1['diff'] = data1.M - data1.F
print data1.head()
# Out:
# Gender                                             F         M      diff
# MovieID Title
# 1       Toy Story (1995)                    4.187817  4.130552 -0.057265
# 2       Jumanji (1995)                      3.278409  3.175238 -0.103171
# 3       Grumpier Old Men (1995)             3.073529  2.994152 -0.079377
# 4       Waiting to Exhale (1995)            2.976471  2.482353 -0.494118
# 5       Father of the Bride Part II (1995)  3.212963  2.888298 -0.324665

# %%
# choose top 50 movies 
most_50 = data.groupby('MovieID').size().order(ascending=False)[:50]
data1.reset_index('MovieID', inplace=True)

# %%
# %matplotlib inline

disagreements = data1[data1.MovieID.isin(most_50.index)]['diff']
disagreements.order().plot(kind='barh', figsize=[9, 15])
plt.title('Male vs. Female Avg. Ratings\n(Difference > 0 = Favored by Men)')
plt.ylabel('Title')
plt.xlabel('Average Rating Difference');

# %% [markdown]
# #### 9. Which occupation watches which Genre the most?

# %%
# values of occupation we found here: https://github.com/pydata/pydata-book/tree/master/ch02/movielens
occupation = ["Genres", "other", "academic/educator", "artist", "clerical/admin", "college/grad student", 
              "customer service", "doctor/health care", "executive/managerial", "farmer", "homemaker",
              "K-12 student", "lawyer", "programmer", "retired", "sales/marketing", "scientist", "self-employed",
              "technician/engineer", "tradesman/craftsman", "unemployed", "writer"]

# %%
# get data with occupation values group by Genres
genres_by_occupation = data.pivot_table('Rating', rows='Genres', cols='Occupation', aggfunc = 'count')

# %%
# next functions allow rename values of genres by first category.
def group_genres(df):
    for i,item in enumerate(df.index):
        word = item.partition('|')
        df['Genres1'] = word[0]
    for i,item in enumerate(df.index):
        word = item.partition('|')
        df['Genres1'][i] = word[0]

# %%
# call a function
group_genres(genres_by_occupation)

# %%
# group by genres
genres_by_occupation = genres_by_occupation.groupby("Genres1", as_index=False)
genres_by_occupation = genres_by_occupation.aggregate(sum)
genres_by_occupation
# Out:
# Occupation      Genres1      0      1      2     3      4     5      6      7  \
# 0                Action  32957  18673  11277  7078  35152  6493   8601  28863
# 1             Adventure   5631   3499   2060  1243   5539  1050   1525   4442
# 2             Animation   4771   2809   1845  1146   6032   804   1338   2935
# 3            Children's   2878   1744    962   708   3097   434    786   2002
# 4                Comedy  36042  24038  14313  9420  37321  6019  10419  27988
# 5                 Crime   4980   3213   1933  1238   4957   724   1393   4158
# 6           Documentary   1010    683    493   251    818    80    257    615
# 7                 Drama  26638  21709  11734  6904  25186  3451   8836  22740
# 8               Fantasy     99     55     36    21     85    21     24     82
# 9             Film-Noir   1160    978    529   364    842   168    333    982
# 10               Horror   7094   2919   2111  1281   5823  1457   1546   4275
# 11              Musical    827    825    450   302    684   122    313    783
# 12              Mystery   1367    984    496   391   1082   159    383   1082
# 13              Romance    384    311    145   128    333    37    130    304
# 14               Sci-Fi   1381    927    544   308   1366   251    370   1145
# 15             Thriller   2423   1444    839   634   2157   396    720   2066
# 16                  War    106     98     28    23     81    13     39    143
# 17              Western    751    442    273   183    477   171    192    820
#
# Occupation    8 ...     11     12    13     14    15     16     17    18  \
# 0           868 ...   4793  17136  2773  13559  6484  11863  23324  3188
# 1           176 ...    875   2674   632   1986  1075   2002   3550   616
# 2           115 ...    624   2224   279   1472   858   1389   2744   294
# 3            84 ...    356   1089   221    833   452    814   1526   239
# 4           687 ...   6076  14860  3608  14058  5934  12517  18097  3179
# 5            78 ...    925   2041   502   2080   823   1768   2512   508
# 6             8 ...    154    347    87    254   135    366    306    63
# 7           453 ...   4551  10679  3957   9908  4839   9732  12555  2079
# 8             4 ...     13     71     9     36    32     33     88     7
# 9            21 ...    282    607   227    408   244    404    646   101
# 10          108 ...    705   2237   431   1785   753   2287   3344  1108
# 11            6 ...    179    306   195    286   140    314    409    53
# 12           17 ...    208    574   212    536   250    484    789   120
# 13            2 ...     52    135    47    127    55    137    136    15
# 14           44 ...    218    951   173    490   313    587   1047   125
# 15           24 ...    346    994   232    993   383    896   1218   265
# 16            2 ...     27     49    34     39    36     76     87    19
# 17            9 ...    179    240   135    259   145    352    438   107
#
# Occupation    19     20
# 0           3706  12504
# 1            613   2604
# 2            454   2274
# 3            383   1269
# 4           4199  17664
# 5            574   2559
# 6            117    665
# 7           2896  14047
# 8             15     40
# 9            137    731
# 10           954   2508
# 11           108    484
# 12           153    673
# 13            49    204
# 14           195    736
# 15           265   1028
# 16             6     67
# 17            80    340
#
# [18 rows x 22 columns]

# %%
# sort by "other" occupation to see with movies they prefer
sorted_by_other = genres_by_occupation.sort_index(by=0)
sorted_by_other.index = range(len(sorted_by_other))
# give the columns right names by occupations
sorted_by_other.columns = occupation
sorted_by_other
# Out:
#          Genres  other  academic/educator  artist  clerical/admin  \
# 0       Fantasy     99                 55      36              21
# 1           War    106                 98      28              23
# 2       Romance    384                311     145             128
# 3       Western    751                442     273             183
# 4       Musical    827                825     450             302
# 5   Documentary   1010                683     493             251
# 6     Film-Noir   1160                978     529             364
# 7       Mystery   1367                984     496             391
# 8        Sci-Fi   1381                927     544             308
# 9      Thriller   2423               1444     839             634
# 10   Children's   2878               1744     962             708
# 11    Animation   4771               2809    1845            1146
# 12        Crime   4980               3213    1933            1238
# 13    Adventure   5631               3499    2060            1243
# 14       Horror   7094               2919    2111            1281
# 15        Drama  26638              21709   11734            6904
# 16       Action  32957              18673   11277            7078
# 17       Comedy  36042              24038   14313            9420
#
#     college/grad student  customer service  doctor/health care  \
# 0                     85                21                  24
# 1                     81                13                  39
# 2                    333                37                 130
# 3                    477               171                 192
# 4                    684               122                 313
# 5                    818                80                 257
# 6                    842               168                 333
# 7                   1082               159                 383
# 8                   1366               251                 370
# 9                   2157               396                 720
# 10                  3097               434                 786
# 11                  6032               804                1338
# 12                  4957               724                1393
# 13                  5539              1050                1525
# 14                  5823              1457                1546
# 15                 25186              3451                8836
# 16                 35152              6493                8601
# 17                 37321              6019               10419
#
#     executive/managerial  farmer   ...    lawyer  programmer  retired  \
# 0                     82       4   ...        13          71        9
# 1                    143       2   ...        27          49       34
# 2                    304       2   ...        52         135       47
# 3                    820       9   ...       179         240      135
# 4                    783       6   ...       179         306      195
# 5                    615       8   ...       154         347       87
# 6                    982      21   ...       282         607      227
# 7                   1082      17   ...       208         574      212
# 8                   1145      44   ...       218         951      173
# 9                   2066      24   ...       346         994      232
# 10                  2002      84   ...       356        1089      221
# 11                  2935     115   ...       624        2224      279
# 12                  4158      78   ...       925        2041      502
# 13                  4442     176   ...       875        2674      632
# 14                  4275     108   ...       705        2237      431
# 15                 22740     453   ...      4551       10679     3957
# 16                 28863     868   ...      4793       17136     2773
# 17                 27988     687   ...      6076       14860     3608
#
#     sales/marketing  scientist  self-employed  technician/engineer  \
# 0                36         32             33                   88
# 1                39         36             76                   87
# 2               127         55            137                  136
# 3               259        145            352                  438
# 4               286        140            314                  409
# 5               254        135            366                  306
# 6               408        244            404                  646
# 7               536        250            484                  789
# 8               490        313            587                 1047
# 9               993        383            896                 1218
# 10              833        452            814                 1526
# 11             1472        858           1389                 2744
# 12             2080        823           1768                 2512
# 13             1986       1075           2002                 3550
# 14             1785        753           2287                 3344
# 15             9908       4839           9732                12555
# 16            13559       6484          11863                23324
# 17            14058       5934          12517                18097
#
#     tradesman/craftsman  unemployed  writer
# 0                     7          15      40
# 1                    19           6      67
# 2                    15          49     204
# 3                   107          80     340
# 4                    53         108     484
# 5                    63         117     665
# 6                   101         137     731
# 7                   120         153     673
# 8                   125         195     736
# 9                   265         265    1028
# 10                  239         383    1269
# 11                  294         454    2274
# 12                  508         574    2559
# 13                  616         613    2604
# 14                 1108         954    2508
# 15                 2079        2896   14047
# 16                 3188        3706   12504
# 17                 3179        4199   17664
#
# [18 rows x 22 columns]

# %% [markdown]
# What we see:
#
# - almost all occupations prefer comedy, action or drama;
#
# - the least popular are Fantasy and War.

# %%
# let's choose 10 occupation and build plot by number of ratings for each genre
occupation1 = occupation[1:10]
df1 = sorted_by_other[occupation1]
# we are plotting with help of pandas method "plot()"
df1.plot(kind='barh', figsize=[25, 10], x=sorted_by_other.Genres, stacked=True);

# %% [markdown]
# ###### # Let's see what films watch writers?

# %%
df = sorted_by_other[['Genres', 'writer']]

# %%
df.plot(kind='line', x=df.Genres, figsize=[9, 3])
plt.title('What movies watch writers?')
plt.ylabel('count')
plt.xlabel('genres');

# %% [markdown]
# #### 10. Which age group is ranking which genre the most?

# %%
# we are dividing people in 8 group by age.
labels = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
# add new column with age_group
data['Age_group'] = pd.cut(data['Age'], range(0, 81, 10), right=False, labels=labels)
print data[['Age', 'Age_group']].drop_duplicates()[:20]
# Out:
#     Age Age_group
# 0     1       0-9
# 1    56     50-59
# 2    25     20-29
# 4    50     50-59
# 5    18     10-19
# 9    45     40-49
# 20   35     30-39

# %%
# let's look at how age is distributed amongst our users
# call panda's "hist" on the column to produce a histogram
data.Age.hist(bins=10)
plt.title("Distribution of users' ages")
plt.ylabel('count of users')
plt.xlabel('age');

# %%
# now we are comparing ratings across age groups
print data.groupby('Age_group').agg({'Rating': [np.size, np.mean]})
# Out:
#            Rating
#              size      mean
# Age_group
# 0-9         27211  3.549520
# 10-19      183536  3.507573
# 20-29      395556  3.545235
# 30-39      199003  3.618162
# 40-49       83633  3.638062
# 50-59      111270  3.732677

# %% [markdown]
# What we see:
#
# - old users are more critical than other.

# %%
# group our data by Genres and Age_group
age_genres = data.pivot_table('Rating', rows='Genres', cols='Age_group', aggfunc = 'count')

# %%
# call a function to join genres
group_genres(age_genres)

# %%
# aggregate genres by sum of each age group
age_genres_count = age_genres.groupby("Genres1", as_index=False)
age_genres_count = age_genres_count.aggregate(sum)

# %%
age_genres_count
# Out:
# Age_group      Genres1   0-9  10-19   20-29  30-39  40-49  50-59
# 0               Action  6578  50186  105678  50503  19357  25155
# 1            Adventure  1456   8260   16064   8981   3862   5007
# 2            Animation  2163   8786   13844   6981   2504   2658
# 3           Children's  1370   4612    7516   4332   1801   1860
# 4               Comedy  7869  53112  111568  53727  22183  28464
# 5                Crime   760   6998   15503   7114   3054   4420
# 6          Documentary   107    908    3019   1466    601    716
# 7                Drama  4154  32872   80183  42418  19785  29215
# 8              Fantasy    18    122     327    186     63     74
# 9            Film-Noir   172   1057    3311   2226    982   1595
# 10              Horror  1320   8461   17829   8912   3822   3826
# 11             Musical   217    835    2003   1737    895   1425
# 12             Mystery   216   1417    3906   2226   1006   1466
# 13             Romance    63    443    1014    578    287    447
# 14              Sci-Fi   275   1865    4279   2504   1133   1408
# 15            Thriller   397   2917    7435   3612   1516   1974
# 16                 War    15     81     198    228    156    313
# 17             Western    61    604    1879   1272    626   1247

# %%
# we are using pandas area-plot for better visualization
age_genres_count.plot(kind = 'area', x = age_genres_count.Genres1, figsize=[15, 6])

# %% [markdown]
# #### 11. What are the 25 most rated movies?

# %%
# we are grouping movies by title
most_rated = data.groupby('Title').size().order(ascending=False)[:25]
print most_rated
# Out:
# Title
# American Beauty (1999)                                   3428
# Star Wars: Episode IV - A New Hope (1977)                2991
# Star Wars: Episode V - The Empire Strikes Back (1980)    2990
# Star Wars: Episode VI - Return of the Jedi (1983)        2883
# Jurassic Park (1993)                                     2672
# Saving Private Ryan (1998)                               2653
# Terminator 2: Judgment Day (1991)                        2649
# Matrix, The (1999)                                       2590
# Back to the Future (1985)                                2583
# Silence of the Lambs, The (1991)                         2578
# Men in Black (1997)                                      2538
# Raiders of the Lost Ark (1981)                           2514
# Fargo (1996)                                             2513
# Sixth Sense, The (1999)                                  2459
# Braveheart (1995)                                        2443
# Shakespeare in Love (1998)                               2369
# Princess Bride, The (1987)                               2318
# Schindler's List (1993)                                  2304
# L.A. Confidential (1997)                                 2288
# Groundhog Day (1993)                                     2278
# E.T. the Extra-Terrestrial (1982)                        2269
# Star Wars: Episode I - The Phantom Menace (1999)         2250
# Being John Malkovich (1999)                              2241
# Shawshank Redemption, The (1994)                         2227
# Godfather, The (1972)                                    2223
# dtype: int64

# %% [markdown]
# #### 12. Which movies are most highly rated?

# %%
# group data by title and fing rating's mean
movie_stats = data.groupby('Title').agg({'Rating': [np.size, np.mean]})
print movie_stats.sort([('Rating', 'mean')], ascending=False).head()
# Out:
#                           Rating
#                             size  mean
# Title
# Ulysses (Ulisse) (1954)        1     5
# Lured (1947)                   1     5
# Follow the Bitch (1998)        1     5
# Bittersweet Motel (2000)       1     5
# Song of Freedom (1936)         1     5

# %%
# for better analysis we only look at movies that have been rated at least 100 times
atleast_100 = movie_stats['Rating'].size >= 100
print movie_stats[atleast_100].sort([('Rating', 'mean')], ascending=False)[:15]
# Out:
#                                                                              Rating  \
#                                                                                size
# Title
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)             628
# Shawshank Redemption, The (1994)                                               2227
# Godfather, The (1972)                                                          2223
# Close Shave, A (1995)                                                           657
# Usual Suspects, The (1995)                                                     1783
# Schindler's List (1993)                                                        2304
# Wrong Trousers, The (1993)                                                      882
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                                   470
# Raiders of the Lost Ark (1981)                                                 2514
# Rear Window (1954)                                                             1050
# Paths of Glory (1957)                                                           230
# Star Wars: Episode IV - A New Hope (1977)                                      2991
# Third Man, The (1949)                                                           480
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)    1367
# Wallace & Gromit: The Best of Aardman Animation (1996)                          438
#
#
#                                                                                  mean
# Title
# Seven Samurai (The Magnificent Seven) (Shichinin no samurai) (1954)          4.560510
# Shawshank Redemption, The (1994)                                             4.554558
# Godfather, The (1972)                                                        4.524966
# Close Shave, A (1995)                                                        4.520548
# Usual Suspects, The (1995)                                                   4.517106
# Schindler's List (1993)                                                      4.510417
# Wrong Trousers, The (1993)                                                   4.507937
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)                                4.491489
# Raiders of the Lost Ark (1981)                                               4.477725
# Rear Window (1954)                                                           4.476190
# Paths of Glory (1957)                                                        4.473913
# Star Wars: Episode IV - A New Hope (1977)                                    4.453694
# Third Man, The (1949)                                                        4.452083
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)  4.449890
# Wallace & Gromit: The Best of Aardman Animation (1996)                       4.426941

# %% [markdown]
# #### 13. Build Regression.

# %%
# get data and group it by movies
movies = data[['Title', 'MovieID']]
movies_count = movies.groupby("Title", as_index=False).size()
movies_count = pd.DataFrame(movies_count)

# %%
# removing year from the title
def get_year(df):
    for i,item in enumerate(df.index):
        year = item[-5:len(item)-1]
        df['Year'] = year
    for i,item in enumerate(df.index):
        year = item[-5:len(item)-1]
        df['Year'][i] = year

# %%
# call function
get_year(movies_count)

# %%
# sort by the most popular 
movies_count = movies_count.sort_index(by=0, ascending=False)
movies_count [:10]
# Out:
#                                                           0  Year
# Title
# American Beauty (1999)                                 3428  1999
# Star Wars: Episode IV - A New Hope (1977)              2991  1977
# Star Wars: Episode V - The Empire Strikes Back (1980)  2990  1980
# Star Wars: Episode VI - Return of the Jedi (1983)      2883  1983
# Jurassic Park (1993)                                   2672  1993
# Saving Private Ryan (1998)                             2653  1998
# Terminator 2: Judgment Day (1991)                      2649  1991
# Matrix, The (1999)                                     2590  1999
# Back to the Future (1985)                              2583  1985
# Silence of the Lambs, The (1991)                       2578  1991

# %%
# reindex data to leave only number of movies and years
movies_count.index = range(len(movies_count))
# rename movies
movies_count.columns = ["num_watches", 'year']
movies_count[:10]
# Out:
#    num_watches  year
# 0         3428  1999
# 1         2991  1977
# 2         2990  1980
# 3         2883  1983
# 4         2672  1993
# 5         2653  1998
# 6         2649  1991
# 7         2590  1999
# 8         2583  1985
# 9         2578  1991

# %%
movies_count[["num_watches", 'year']].describe()
# Out:
#        num_watches
# count  3706.000000
# mean    269.889099
# std     384.047838
# min       1.000000
# 25%      33.000000
# 50%     123.500000
# 75%     350.000000
# max    3428.000000

# %%
# get values of number and years to build regression
y = np.array(movies_count['num_watches'], dtype=float)
x = np.array(movies_count['year'], dtype=float)

# %%
# we are using numpy and pylab library to get coefficients and build plot 

# fit with np.polyfit
m, b = np.polyfit(x, y, 1)
m, b
# Out:
# (0.5856528396342634, -893.27559516531483)

# %%
# plot x, y and line
plt.plot(x, y, '.')
plt.plot(x, m*x + b, '-')

# %%
# let's try use other library, for example scipy and build regression 
from scipy import stats

# %%
# get statistic values 
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

print 'r value', r_value
print  'p_value', p_value
print 'standard deviation', std_err

# build plot
line = slope*x+intercept
plot(x,y,'o')
plot(x,line,'r-')
# Out:
# r value 0.0253418812552
# p_value 0.122961104909
# standard deviation 0.37960018344

# %% [markdown]
# #### 14. Test for significance.

# %%
# descriptive Statistics
print x.max(), x.min()
# Out:
# 2000.0 1919.0

# %%
print x.mean(), x.var()
# Out:
# 1986.09929843 276.089977921

# %%
#some sample properties compare to their theoretical counterparts
sstr = 'mean = %6.4f, variance = %6.4f, skew = %6.4f, kurtosis = %6.4f'
m, v, s, k = stats.t.stats(10, moments='mvsk')
print sstr %(m, v, s ,k)
# Out:
# mean = 0.0000, variance = 1.2500, skew = 0.0000, kurtosis = 1.0000

# %%
n, (smin, smax), sm, sv, ss, sk = stats.describe(x)
print sstr %(sm, sv, ss, sk)
# Out:
# mean = 1986.0993, variance = 276.1645, skew = -1.7348, kurtosis = 2.3012

# %%
# in our case the sample statistics differ a by a small amount from their theoretical counterparts.

# %%
# we are using  the t-test to test whether the mean of our sample differs in a statistcally significant way from the theoretical expectation.
print 't-statistic = %6.3f pvalue = %6.4f' %  stats.ttest_1samp(x, m)
# Out:
# t-statistic = 7275.616 pvalue = 0.0000

# %%
# the Kolmogorov-Smirnov test can be used to test the hypothesis that the sample comes from the standard t-distribution
print 'KS-statistic D = %6.3f pvalue = %6.4f' % stats.kstest(x, 't', (10,))
# Out:
# KS-statistic D =  1.000 pvalue = 0.0000

# %% [markdown]
# In both cases p-value = 0, it means that the data comes from a Normal distribution.

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-ed9806ce3570> in <module>()
# ----> 1 import seaborn as sns
#
# ImportError: No module named seaborn

# %%
import seaborn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-085c0287ecb5> in <module>()
# ----> 1 import seaborn
#
# ImportError: No module named seaborn
